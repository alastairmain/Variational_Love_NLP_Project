# %%
#!pip install torchtext

# %%
from torchtext.data import Dataset, BucketIterator, Field, TabularDataset, Iterator
from torchtext.vocab import Vocab
import pandas as pd
import numpy as np
import spacy

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch import nn
from random import shuffle

# %%
from torch.nn import Linear
from torch.nn.functional import softmax, relu

from sklearn.manifold import TSNE

# we'll use the bokeh library to create beautiful plotstttfttftftft
# *_notebook functions are needed for correct use in jupyter
from bokeh.plotting import figure, ColumnDataSource
from bokeh.models import HoverTool
from bokeh.io import output_notebook, show, push_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2645cd9b-9fb1-47c3-bf4b-d19ca5d85587">Loading BokehJS ...</span>
#     </div>

# %%
use_cuda = torch.cuda.is_available()

def get_variable(x):
    """ Converts tensors to cuda, if available. """
    if use_cuda:
        return x.cuda()
    return x

def get_numpy(x):
    """ Get numpy array for both cuda and not. """
    if use_cuda:
        return x.cpu().data.numpy()
    return x.data.numpy()

# %%
def condence(nparr):
    uniq = np.unique(nparr)
    name2idx = {o:i for i,o in enumerate(uniq)}
    return np.array([name2idx[o] for o in nparr]), uniq

## Read set
data='raw-data.csv'
interactions = 'user-info-small.csv'
rawtext = pd.read_csv(data)
interactions = pd.read_csv(interactions)
interactions["user.id"], uniq = condence(interactions["user.id"].values)
sizes = [0.7, 0.2]

iteractions = np.random.shuffle(interactions.values) # Shuffle
interactions["doc.id"] = [rawtext.iloc[int(idx),1] for idx in interactions["doc.id"]]

n = len(interactions)
train_size = int(sizes[0] * n)
val_size = int(sizes[1] * n)
test_size = n - train_size - val_size

train = interactions[:train_size]
val = interactions[train_size:train_size+val_size]
test = interactions[train_size+val_size:]

n = len(train)

uniq_items = np.unique(rawtext["doc.id"])[:-1]
uniq_users = np.unique(train["user.id"])[:-1]
items = set((x[0],x[1]) for x in train[["user.id","doc.id"]].values)

pairs = []
i = 0
while(i < n):
    
    item = np.random.choice(uniq_items, size = 1)[0]
    user = np.random.choice(uniq_users, size = 1)[0]
    if (user,item) not in items:
        i += 1
        pairs += [(user,item,0)]
        items.add((user,item))

interactionsNegatives = np.vstack((train, pairs))

train = pd.DataFrame(data = interactionsNegatives,
                                    columns = ["user.id","doc.id", "rating"]
                                    )


train["doc.id"].loc[n:] = [rawtext.iloc[int(idx),1] for idx in train["doc.id"].loc[n:]]

train = train.sample(frac=1) #shuffle panda style

train.to_csv('citeulike2/train.csv', header = False, index = False)
val.to_csv('citeulike2/val.csv', header = False, index = False)
test.to_csv('citeulike2/test.csv', header = False, index = False)

# %%
print(rawtext.head)
# Out:
# <bound method NDFrame.head of       doc.id                                              title citeulike.id  \
# 0          1  the metabolic world of escherichia coli is not...           42
# 1          2       reverse engineering of biological complexity           43
# 2          3                         exploring complex networks           44
# 3          4  comparative assessment of largescale data sets...           46
# 4          5                        navigation in a small world           47
# 5          6  random graphs with arbitrary degree distributi...           48
# 6          7  artificial gene networks for objective compari...           49
# 7          8  the segment polarity network is a robust devel...           50
# 8          9        the evolutionary origin of complex features           52
# 9         10  early language acquisition cracking the speech...           60
# 10        11  organization development and function of compl...           61
# 11        12                           motifs in brain networks           62
# 12        13  diffusion on complex networks a way to probe t...           97
# 13        14      topological generalizations of network motifs           98
# 14        15         collective dynamics of smallworld networks           99
# 15        16  network motifs simple building blocks of compl...          101
# 16        17  authoritative sources in a hyperlinked environ...          102
# 17        18  the anatomy of a largescale hypertextual web s...          114
# 18        19     spectra and eigenvectors of scalefree networks          122
# 19        20  spectra of random graphs with given expected d...          123
# 20        21  functional discovery via a compendium of expre...          124
# 21        22  growing and navigating the small world web by ...          127
# 22        23  the structure of scientific collaboration netw...          128
# 23        24                     classes of smallworld networks          129
# 24        25  spectra of realworld graphs beyond the semicir...          139
# 25        26  multistability in the lactose utilization netw...          148
# 26        27  protein complexes and functional modules in mo...          151
# 27        28  finding and evaluating community structure in ...          154
# 28        29     the structure and function of complex networks          155
# 29        30                        matching words and pictures          156
# ...      ...                                                ...          ...
# 33931  16951  data structures and compression algorithms for...      8017832
# 33932  16952  atomiclevel characterization of the structural...      8018468
# 33933  16953             twitter mood predicts the stock market      8020393
# 33934  16954  comparing de novo assemblers for transcriptome...      8031121
# 33935  16955  statistical analysis strategies for associatio...      8044039
# 33936  16956               names are key to the big new biology      8050403
# 33937  16957  the peculiar velocity field constraining the t...      8062101
# 33938  16958  nonsynonymous and synonymous coding snps show ...      8126391
# 33939  16959  conflicts of interest at medical journals the ...      8130437
# 33940  16960  a map of human genome variation from populatio...      8133402
# 33941  16961  the patterns and dynamics of genomic instabili...      8133692
# 33942  16962  distant metastasis occurs late during the gene...      8133695
# 33943  16963  wholegenome sequencing and comprehensive varia...      8136692
# 33944  16964  diversity of human copy number variation and m...      8140882
# 33945  16965    dindel accurate indel calls from shortread data      8148870
# 33946  16966  simultaneous falsification of lcdm and quintes...      8175043
# 33947  16967  cagrid workflow toolkit a taverna based workfl...      8208972
# 33948  16968  exploring the universe of protein structures b...      8210118
# 33949  16969  fragseq transcriptomewide rna structure probin...      8218284
# 33950  16970  the honey bee epigenomes differential methylat...      8229116
# 33951  16971  transposable element insertions have strongly ...      8243817
# 33952  16972  experimental demonstration of informationtoene...      8245179
# 33953  16973  genetic interactions reveal the evolutionary t...      8255128
# 33954  16974  concentric circles in wmap data may provide ev...      8266079
# 33955  16975  analysing biological pathways in genomewide as...      8270407
# 33956  16976  life is physics evolution as a collective phen...      8273254
# 33957  16977  limitations of nextgeneration genome sequence ...      8290615
# 33958  16978  accurate inference of transcription factor bin...      8305197
# 33959  16979  software that goes with the flow in systems bi...      8331304
# 33960  16980  a bacterium that can grow by using arsenic ins...      8349297
#
#                                                raw.title  \
# 0      The metabolic world of Escherichia coli is not...
# 1           Reverse Engineering of Biological Complexity
# 2                             Exploring complex networks
# 3      Comparative assessment of large-scale data set...
# 4                            Navigation in a small world
# 5      Random graphs with arbitrary degree distributi...
# 6      Artificial gene networks for objective compari...
# 7      The segment polarity network is a robust devel...
# 8           The evolutionary origin of complex features.
# 9      Early language acquisition: cracking the speec...
# 10     Organization, development and function of comp...
# 11                             Motifs in brain networks.
# 12     Diffusion on Complex Networks : A way to probe...
# 13         Topological Generalizations of network motifs
# 14        Collective dynamics of 'small-world' networks.
# 15     Network motifs: simple building blocks of comp...
# 16     Authoritative sources in a hyperlinked environ...
# 17     The anatomy of a large-scale hypertextual Web ...
# 18      Spectra and eigenvectors of scale-free networks.
# 19     Spectra of random graphs with given expected d...
# 20     Functional discovery via a compendium of expre...
# 21     Growing and navigating the small world Web by ...
# 22     The structure of scientific collaboration netw...
# 23                       Classes of small-world networks
# 24     Spectra of "real-world" graphs: beyond the sem...
# 25     Multistability in the lactose utilization netw...
# 26     Protein complexes and functional modules in mo...
# 27     Finding and evaluating community structure in ...
# 28        The structure and function of complex networks
# 29                           Matching words and pictures
# ...                                                  ...
# 33931  Data structures and compression algorithms for...
# 33932  Atomic-Level Characterization of the Structura...
# 33933             Twitter mood predicts the stock market
# 33934  Comparing de novo assemblers for 454 transcrip...
# 33935  Statistical analysis strategies for associatio...
# 33936               Names are key to the big new biology
# 33937  The peculiar velocity field: constraining the ...
# 33938  Non-synonymous and synonymous coding SNPs show...
# 33939  Conflicts of Interest at Medical Journals: The...
# 33940  A map of human genome variation from populatio...
# 33941  The patterns and dynamics of genomic instabili...
# 33942  Distant metastasis occurs late during the gene...
# 33943  Whole-genome sequencing and comprehensive vari...
# 33944  Diversity of human copy number variation and m...
# 33945  Dindel: Accurate indel calls from short-read d...
# 33946  Simultaneous Falsification of LCDM and Quintes...
# 33947  CaGrid Workflow Toolkit: A taverna based workf...
# 33948  Exploring the Universe of Protein Structures b...
# 33949  FragSeq: transcriptome-wide RNA structure prob...
# 33950  The Honey Bee Epigenomes: Differential Methyla...
# 33951  Transposable element insertions have strongly ...
# 33952  Experimental demonstration of information-to-e...
# 33953  Genetic interactions reveal the evolutionary t...
# 33954  Concentric circles in WMAP data may provide ev...
# 33955  Analysing biological pathways in genome-wide a...
# 33956  Life is physics: evolution as a collective phe...
# 33957  Limitations of next-generation genome sequence...
# 33958  Accurate inference of transcription factor bin...
# 33959  Software that goes with the flow in systems bi...
# 33960  A Bacterium That Can Grow by Using Arsenic Ins...
#
#                                             raw.abstract
# 0      To elucidate the organizational and evolutiona...
# 1      Advanced technologies and biology have extreme...
# 2      The study of networks pervades all of science,...
# 3      Comprehensive protein protein interaction maps...
# 4      The small-world phenomenon — the principle tha...
# 5      Recent work on the structure of social network...
# 6      Motivation: Large-scale gene expression profil...
# 7      All insects possess homologous segments, but s...
# 8      A long-standing challenge to evolutionary theo...
# 9      Infants learn language with remarkable speed, ...
# 10      Recent research has revealed general principl...
# 11     Complex brains have evolved a highly efficient...
# 12     A diffusion process on complex networks is int...
# 13     Biological and technological networks contain ...
# 14     Networks of coupled dynamical systems have bee...
# 15     Complex networks are studied across many field...
# 16     The network structure of a hyperlinked environ...
# 17     Abstract In this paper, we present Google, a p...
# 18     We study the spectra and eigenvectors of the a...
# 19     In the study of the spectra of power-law graph...
# 20     Ascertaining the impact of uncharacterized per...
# 21     Can we model the scale-free distribution of We...
# 22     The structure of scientific collaboration netw...
# 23     We study the statistical properties of a varie...
# 24     Many natural and social systems develop comple...
# 25     Multistability, the capacity to achieve multip...
# 26     Proteins, nucleic acids, and small molecules f...
# 27     We propose and study a set of algorithms for d...
# 28     Inspired by empirical studies of networked sys...
# 29     We present a new approach for modeling multi-m...
# ...                                                  ...
# 33931  BACKGROUND:High-throughput sequencing (HTS) te...
# 33932  Molecular dynamics (MD) simulations are widely...
# 33933  Behavioral economics tells us that emotions ca...
# 33934  BACKGROUND:Roche 454 pyrosequencing has become...
# 33935  The limitations of genome-wide association (GW...
# 33936   Those who seek answers to big, broad question...
# 33937  A large bulk flow, which is in tension with th...
# 33938  Many DNA variants have been identified on more...
# 33939  Transparency in reporting of conflict of inter...
# 33940  The 1000 Genomes Project aims to provide a dee...
# 33941  Pancreatic cancer is an aggressive malignancy ...
# 33942  Metastasis, the dissemination and growth of ne...
# 33943  We report the analysis of a Japanese male usin...
# 33944  Copy number variants affect both disease and n...
# 33945  Small insertions and deletions (indels) are a ...
# 33946  Observation of even a single massive cluster, ...
# 33947  BACKGROUND:In biological and medical domain, t...
# 33948  It is currently believed that the atlas of exi...
# 33949  Classical approaches to determine structures o...
# 33950  In honey bees ( Apis mellifera ) the behaviora...
# 33951  Comparison of a full collection of the transpo...
# 33952  In 1929, Leó Szilárd invented a feedback proto...
# 33953  The characterization of functional redundancy ...
# 33954  Conformal cyclic cosmology (CCC) posits the ex...
# 33955   Genome-wide association (GWA) studies have ty...
# 33956  Evolution is the fundamental physical process ...
# 33957  High-throughput sequencing technologies promis...
# 33958  Accurate functional annotation of regulatory e...
# 33959  ABSTRACT: A recent article in BMC Bioinformati...
# 33960  Life is mostly composed of the elements carbon...
#
# [33961 rows x 5 columns]>

# %%
spacy_en = spacy.load('en')

def tokenizer(text): # create a tokenizer function
    return [tok.text for tok in spacy_en.tokenizer(text)]

TEXT = Field(sequential=True, lower=True)
LABEL = Field(sequential=False, use_vocab=False)
ID = Field(sequential=False, use_vocab=False)

train, val, test = TabularDataset.splits(
        path='citeulike2', train='train.csv',
        validation='val.csv', test='test.csv', format='csv',
        fields=[('ID', ID), ('Text', TEXT), ('Label', LABEL)])

TEXT.build_vocab(train, vectors="glove.6B.100d")
LABEL.build_vocab(train)
ID.build_vocab(train)

# %%
print('Text fields:')
#print('keys of TEXT.vocab:', list(TEXT.vocab.__dict__.keys()))
#print(' size of vocabulary:', len(TEXT.vocab))
print(" vocabulary's embedding dimension:", TEXT.vocab.vectors.size())
print(' no. times the "fun" appear in the dataset:', TEXT.vocab.freqs['fun'])

print('\nLabel fields:')
#print('keys of LABEL.vocab:', list(LABEL.vocab.__dict__.keys()))
print(" list of vocabulary (int-to-str):", LABEL.vocab.itos)
print(" list of vocabulary (str-to-int):", dict(LABEL.vocab.stoi))



print(data)
# Out:
# Text fields:
#  vocabulary's embedding dimension: torch.Size([5082, 100])
#  no. times the "fun" appear in the dataset: 1
#
# Label fields:
#  list of vocabulary (int-to-str): ['<unk>', '0', '1']
#  list of vocabulary (str-to-int): {'<unk>': 0, '0': 1, '1': 2}
# raw-data.csv

# %%
batch_size = (30, 30, 30)

train_iter, val_iter, test_iter = BucketIterator.splits(
    (train, val, test), batch_sizes=batch_size, sort_key=lambda x: len(x.Text))

# %%
# print batch information
batch = next(iter(train_iter))
print("dimension of batch's text:", batch.Text.size())
print("first sequence in text:", batch.Text[:,0])
print("correct label index:", batch.Label[0])
print("the actual label:", LABEL.vocab.itos[get_numpy(batch.Label[0])])
# Out:
# dimension of batch's text: torch.Size([16, 30])
# first sequence in text: tensor([  195,  4918,    12,    22,  2964,     6,    57,  2314,     1,
#             1,     1,     1,     1,     1,     1,     1])
# correct label index: tensor(1)
# the actual label: 0

# %% [markdown]
# Bag of Words Model

# %%
# size of embeddings
embedding_dim = TEXT.vocab.vectors.size()[1]
num_embeddings = TEXT.vocab.vectors.size()[0]
num_classes = len(LABEL.vocab.itos)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # use pretrained embeddings
        self.embeddings.weight.data.copy_(TEXT.vocab.vectors)
        
        # add hidden layers
        # YOUR CODE HERE!
        self.l_1 = Linear(in_features=embedding_dim,
                           out_features=30,
                           bias=True)
        self.l_2 = Linear(in_features=30,
                           out_features=30,
                           bias=True)
        
        self.dropout1 = nn.Dropout(p=0.5)
        self.dropout2 = nn.Dropout(p=0.5)
        self.dropout3 = nn.Dropout(p=0.5)
        
        # output layer
        self.l_out = Linear(in_features=30,
                            out_features=num_classes,
                            bias=False)
        
    def forward(self, x):
        out = {}
        # get embeddings
        x = self.embeddings(x)
        
        # mean embeddings, this is the bag of words trick
        out['bow'] = x = torch.mean(x, dim=0)
        
        # add hidden layers
        # YOUR CODE HERE!
        out['l1_activations'] = x = self.dropout1(relu(self.l_1(x)))
        out['l2_activations'] = x = self.dropout2(relu(self.l_2(x)))


        # Softmax
        out['out'] = softmax(self.l_out(x), dim=1)
        return out

net = Net()

print(net)
# Out:
# Net(
#   (embeddings): Embedding(5073, 100)
#   (l_1): Linear(in_features=100, out_features=30, bias=True)
#   (l_2): Linear(in_features=30, out_features=30, bias=True)
#   (dropout1): Dropout(p=0.5)
#   (dropout2): Dropout(p=0.5)
#   (dropout3): Dropout(p=0.5)
#   (l_out): Linear(in_features=30, out_features=3, bias=False)
# )

# %%
print(LABEL.vocab.itos)
# Out:
# ['<unk>', '0', '1']

# %%
criterion = nn.CrossEntropyLoss()
#criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-5)

def accuracy(ys, ts):
    # making a one-hot encoded vector of correct (1) and incorrect (0) predictions
    correct_prediction = torch.eq(torch.max(ys, 1)[1], ts)
    # averaging the one-hot encoded vector
    return torch.mean(correct_prediction.float())

# %%
def construct_sentences(batch):
    """    
    Parameters
    ----------
    batch: torchtext.data.batch.Batch
    
    Returns
    -------
    [str]
    """
    return [" ".join([TEXT.vocab.itos[elm] 
                      for elm in get_numpy(batch.Text[:,i])])
            for i in range(batch.Text.size()[1])]

def get_labels(batch):
    """
    Parameters
    ----------
    batch: torchtext.data.batch.Batch
    
    Returns
    -------
    [str]
    """
    return [LABEL.vocab.itos[get_numpy(batch.Label[i])] for i in range(len(batch.Label))]

# %%
# to project our hidden embeddings to a visualizable space
tsne = TSNE(perplexity=10.0, learning_rate=5.0, n_iter=2000)

# index for each label
colormap = {1: 'DodgerBlue', 2: 'FireBrick'}

# create a tmp source to be updated later
validation_set_size = len(val)
source = ColumnDataSource(data={'x': np.random.randn(validation_set_size),
                                'y': np.random.randn(validation_set_size),
                                'colors': ['green']*validation_set_size,
                                'sentences': ["tmp"]*validation_set_size,
                                'labels': ["unk"]*validation_set_size})

# instance to define hover logic in plot
hover = HoverTool(tooltips=[("Sentence", "@sentences"), ("Label", "@labels")])

# set up the bokeh figure for later visualizations
p = figure(tools=[hover])
p.circle(x='x', y='y', fill_color='colors', size=5, line_color=None, source=source)

def update_plot(meta, layer, handle):
    """ 
    Update existing plot
    
    Parameters
    ----------
    meta: dict
    layer: str
    """
    tsne_acts = tsne.fit_transform(meta[layer])
    source.data['x'] = tsne_acts[:,0]
    source.data['y'] = tsne_acts[:,1]
    source.data['colors'] = [colormap[l] for l in meta['label_idx']]
    
    source.data['sentences'] = meta['sentences']
    source.data['labels'] = meta['labels']
    
    # this updates the given plot
    push_notebook(handle=handle)

# %%
max_iter = 3000
eval_every = 1000
log_every = 200

# will be updated while iterating
tsne_plot = show(p, notebook_handle=True)

train_loss, train_accs = [], []

net.train()
for i, batch in enumerate(train_iter):
    if i % eval_every == 0:
        net.eval()
        val_losses, val_accs, val_lengths = 0, 0, 0
        val_meta = {'label_idx': [], 'sentences': [], 'labels': []}
        for val_batch in val_iter:
            output = net(val_batch.Text)
            # batches sizes might vary, which is why we cannot just mean the batch's loss
            # we multiply the loss and accuracies with the batch's size,
            # to later divide by the total size
            val_losses += criterion(output['out'], val_batch.Label) * val_batch.batch_size
            val_accs += accuracy(output['out'], val_batch.Label) * val_batch.batch_size
            val_lengths += val_batch.batch_size
            
            for key, _val in output.items():
                if key not in val_meta:
                    val_meta[key] = []
                val_meta[key].append(get_numpy(_val)) 
            val_meta['label_idx'].append(get_numpy(val_batch.Label))
            val_meta['sentences'].append(construct_sentences(val_batch))
            val_meta['labels'].append(get_labels(val_batch))
        
        for key, _val in val_meta.items():
            val_meta[key] = np.concatenate(_val)
        
        # divide by the total accumulated batch sizes
        val_losses /= val_lengths
        val_accs /= val_lengths
        
        print("valid, it: {} loss: {:.2f} accs: {:.2f}\n".format(i, get_numpy(val_losses), get_numpy(val_accs)))
        update_plot(val_meta, 'bow', tsne_plot)
        
        net.train()
    
    output = net(batch.Text)
    batch_loss = criterion(output['out'], batch.Label)
    
    train_loss.append(get_numpy(batch_loss))
    train_accs.append(get_numpy(accuracy(output['out'], batch.Label)))
    
    optimizer.zero_grad()
    batch_loss.backward()
    optimizer.step()
    
    if i % log_every == 0:        
        print("train, it: {} loss: {:.2f} accs: {:.2f}".format(i, 
                                                               np.mean(train_loss), 
                                                               np.mean(train_accs)))
        # reset
        train_loss, train_accs = [], []
        
    if max_iter < i:
        break
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7380e74f-cb99-46a1-a206-ffdf650a8d9a"></div>
# </div>
# /Users/alastairmain/.local/lib/python3.6/site-packages/torchtext/data/field.py:322: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# valid, it: 0 loss: 1.10 accs: 0.05
#
# train, it: 0 loss: 1.09 accs: 0.50
# train, it: 200 loss: 0.99 accs: 0.50
# train, it: 400 loss: 0.97 accs: 0.50
# train, it: 600 loss: 0.96 accs: 0.50
# train, it: 800 loss: 0.96 accs: 0.50
# valid, it: 1000 loss: 0.99 accs: 0.00
#
# train, it: 1000 loss: 0.96 accs: 0.50
# train, it: 1200 loss: 0.96 accs: 0.50
# train, it: 1400 loss: 0.96 accs: 0.52
# train, it: 1600 loss: 0.94 accs: 0.59
# train, it: 1800 loss: 0.83 accs: 0.74
# valid, it: 2000 loss: 0.98 accs: 0.56
#
# train, it: 2000 loss: 0.71 accs: 0.86
# train, it: 2200 loss: 0.67 accs: 0.89
# train, it: 2400 loss: 0.65 accs: 0.91
# train, it: 2600 loss: 0.64 accs: 0.92
# train, it: 2800 loss: 0.64 accs: 0.92
# valid, it: 3000 loss: 1.00 accs: 0.56
#
# train, it: 3000 loss: 0.63 accs: 0.93

# %%
# Vi har prøvet at bruge dropout og weight deca for at forhindre ovefitting.... Det gik ikke så godt, har vi andre ideer?
